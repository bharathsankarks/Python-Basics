# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathsankarks/Python-Basics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=('a','b','c','d','e')
y=('20','10','30','25','44')

# %%
plt.bar(x,y,width=0.4,color='b')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y,color='r')
# Out:
# <BarContainer object of 5 artists>

# %%
import seaborn as sns

# %%
x=('o','r','g','h','k')
y=('22','20','40','25','10')

# %%
iris=sns.load_dataset("iris")

# %%
sns.lineplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
